# %% [markdown]
# ## 1. Data Structures
#
# - List: [], list()
# - Set:{}, set()
# - Dictionary

# %% [markdown]
# ## 1.1 List
# .[], list()
# . Có thể lưu trữ được nhiều kiểu dữ liệu khác nhau
# . Indexing, có thứ tự của các phần tử

# %%
li = [1,2,3, 'Truong', False, True, None, 1 + 2j]

# %%
[method for method in dir(li) if not method.startswith('__')]
# Out:
# ['append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
li.append('tien')

# %%
li
# Out:
# [1, 2, 3, 'Truong', False, True, None, (1+2j), 'tien']

# %%
li.clear()

# %%
li
# Out:
# [1, 2, 3, 'Truong', False, True, None, (1+2j)]

# %%
li[3]
# Out:
# 'Truong'

# %%
li[True]
# Out:
# 2

# %%
li[3:6]
# Out:
# ['Truong', False, True]

# %%
li.append('9,10,11')

# %%
li
# Out:
# [1, 2, 3, 'Truong', False, True, None, (1+2j), '9,10,11']

# %%
li.remove('9,10,11')

# %%
li
# Out:
# [1, 2, 3, 'Truong', False, True, None, (1+2j)]

# %%
li.count(2)
# Out:
# 1

# %%
li.extend([8,9,10])

# %%
li
# Out:
# [1, 2, 3, 'Truong', False, True, None, (1+2j), 8, 9, 10]

# %%
li.pop(3)
# Out:
# 'Truong'

# %%
li
# Out:
# [1, 2, 3, False, True, None, (1+2j), 8, 9, 10]

# %%
li.reverse()

# %%
li
# Out:
# [1, 2, 3, False, True, None, (1+2j), 8, 9, 10]

# %%
li.remove(False, True, None, (1+2j))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-3c43485df4c5> in <module>
# ----> 1 li.remove(False, True, None, (1+2j))
#
# TypeError: remove() takes exactly one argument (4 given)

# %%
li.index(False)
# Out:
# 0

# %%
li.remove('9,10')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-54-0c2344ec6462> in <module>
# ----> 1 li.remove('9,10')
#
# ValueError: list.remove(x): x not in list

# %%
li
# Out:
# [False, 1, True, 2, 3, None, (1+2j), 9, 10]

# %%
li.clear(5:7)
# Out:
#   File "<ipython-input-56-739f7e13a9bd>", line 1
#     li.clear(5:7)
#               ^
# SyntaxError: invalid syntax

# %%
li.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-1bd59660c28b> in <module>
# ----> 1 li.sort()
#
# TypeError: '<' not supported between instances of 'NoneType' and 'int'

# %% [markdown]
# ### 1.2 Tupe
#
# - Immutable --> Khong the thay doi duoc gia tri
# - Indexing --> giong list
# - (), tuple()

# %%
tup_1 = (1,2,3,4)

# %%
tup_1
# Out:
# (1, 2, 3, 4)

# %%
tup_1[0] = 3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-60-935f5d899f62> in <module>
# ----> 1 tup_1[0] = 3
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ### 1.2 Set
# - Khong co phan tu trung lap
# - Non-indexing
# - Unordered

# %%
set_1 = {3,4,4,5,55,55, 'Truong'}
set_1
# Out:
# {3, 4, 5, 55, 'Truong'}

# %%
[method for method in dir(set_1) if not method.startswith('__')]
# Out:
# ['add',
#  'clear',
#  'copy',
#  'difference',
#  'difference_update',
#  'discard',
#  'intersection',
#  'intersection_update',
#  'isdisjoint',
#  'issubset',
#  'issuperset',
#  'pop',
#  'remove',
#  'symmetric_difference',
#  'symmetric_difference_update',
#  'union',
#  'update']

# %%
set_1.add(9)

# %%
set_1
# Out:
# {3, 4, 5, 55, 9, 'Truong'}

# %%
set_1.copy()
# Out:
# {3, 4, 5, 55, 9, 'Truong'}

# %%
set_3 = set_1

# %%
set_3
# Out:
# {3, 4, 5, 55, 9, 'Truong'}

# %%
set_3 = set_1.copy()

# %%
set_3
# Out:
# {3, 4, 5, 55, 9, 'Truong'}

# %%
set_4 =
